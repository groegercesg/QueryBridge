# %%
from numpy import char
from datetime import date
import pandas as pd
import numpy as np
import time
pd.set_option('display.float_format', str)

# %%
import pandas as pd


# Lineitem

l_columnnames = ["L_ORDERKEY", "L_PARTKEY", "L_SUPPKEY", "L_LINENUMBER", "L_QUANTITY", "L_EXTENDEDPRICE", "L_DISCOUNT", "L_TAX",
                "L_RETURNFLAG", "L_LINESTATUS", "L_SHIPDATE", "L_COMMITDATE", "L_RECEIPTDATE", "L_SHIPINSTRUCT", "L_SHIPMODE", "L_COMMENT"]

for i in range(len(l_columnnames)):
    l_columnnames[i] = l_columnnames[i].lower()

l_data_types = {
    'l_orderkey': int,
    'l_partkey': int,
    'l_suppkey': int,
    'l_linenumber': int,
    'l_quantity': float,
    'l_extendedprice': float,
    'l_discount': float,
    'l_tax': float,
    'l_returnflag': str,
    'l_linestatus': str,
    'l_shipinstruct': str,
    'l_shipmode': str,
    'l_comment': str
}

l_parse_dates = ['l_shipdate', 'l_commitdate', 'l_receiptdate']

# Don't set indexes, as we can't access them with Pandas selection!
lineitem = pd.read_table("../data_storage/lineitem.tbl.csv", sep="|", names=l_columnnames, dtype=l_data_types, parse_dates=l_parse_dates)

# Order

o_columnnames = ["O_ORDERKEY", "O_CUSTKEY", "O_ORDERSTATUS", "O_TOTALPRICE", "O_ORDERDATE", "O_ORDERPRIORITY", "O_CLERK", "O_SHIPPRIORITY", "O_COMMENT"]

for i in range(len(o_columnnames)):
    o_columnnames[i] = o_columnnames[i].lower()
    
o_data_types = {
    'o_orderkey': int,
    'o_custkey': int,
    'o_orderstatus': str,
    'o_totalprice': float,
    'o_orderpriority': str,
    'o_clerk': str,
    'o_shippriority': int,
    'o_comment': str
}

o_parse_dates = ['o_orderdate']

# Don't set indexes, as we can't access them with Pandas selection!
orders = pd.read_table("../data_storage/orders.tbl.csv", sep="|", names=o_columnnames, dtype=o_data_types, parse_dates=o_parse_dates)

# Customer

c_columnnames = ["C_CUSTKEY", "C_NAME", "C_ADDRESS", "C_NATIONKEY", "C_PHONE", "C_ACCTBAL", "C_MKTSEGMENT", "C_COMMENT"]

for i in range(len(c_columnnames)):
    c_columnnames[i] = c_columnnames[i].lower()
    
c_data_types = {
    'c_custkey': int,
    'c_name': str,
    'c_address': str,
    'c_nationkey': int,
    'c_phone': str,
    'c_acctbal': float,
    'c_mktsegment': str,
    'c_comment': str
}

c_parse_dates = []

# Don't set indexes, as we can't access them with Pandas selection!
customer = pd.read_table("../data_storage/customer.tbl.csv", sep="|", names=c_columnnames, dtype=c_data_types, parse_dates=c_parse_dates)

# Part

p_columnnames = ["P_PARTKEY", "P_NAME", "P_MFGR", "P_BRAND", "P_TYPE", "P_SIZE", "P_CONTAINER", "P_RETAILPRICE", "P_COMMENT"]

for i in range(len(p_columnnames)):
    p_columnnames[i] = p_columnnames[i].lower()
    
p_data_types = {
    'p_partkey': int, 
    'p_name': str,
    'p_mfgr': str,
    'p_brand': str,
    'p_type': str,
    'p_size': int,
    'p_container': str,
    'p_retailprice': float,
    'p_comment': str
}

p_parse_dates = []

# Don't set indexes, as we can't access them with Pandas selection!
part = pd.read_table("../data_storage/part.tbl.csv", sep="|", names=p_columnnames, dtype=p_data_types, parse_dates=p_parse_dates)

# Nation

n_columnnames = ["N_NATIONKEY", "N_NAME", "N_REGIONKEY", "N_COMMENT"]

for i in range(len(n_columnnames)):
    n_columnnames[i] = n_columnnames[i].lower()
    
n_data_types = {
    'n_nationkey': int,
    'n_name': str,
    'n_regionkey': int,
    'n_comment': str,
}

n_parse_dates = []

# Don't set indexes, as we can't access them with Pandas selection!
nation = pd.read_table("../data_storage/nation.tbl.csv", sep="|", names=n_columnnames, dtype=n_data_types, parse_dates=n_parse_dates)

# Supplier

s_columnnames = ["S_SUPPKEY", "S_NAME", "S_ADDRESS", "S_NATIONKEY", "S_PHONE", "S_ACCTBAL", "S_COMMENT"]

for i in range(len(s_columnnames)):
    s_columnnames[i] = s_columnnames[i].lower()

s_data_types = {
    's_suppkey': int,
    's_name': str,
    's_address': str,
    's_nationkey': int,
    's_phone': str,
    's_acctbal': float,
    's_comment': str
}

s_parse_dates = []

# Don't set indexes, as we can't access them with Pandas selection!
# Don't set indexes, as we can't access them with Pandas selection!
supplier = pd.read_table("../data_storage/supplier.tbl.csv", sep="|", names=s_columnnames, dtype=s_data_types, parse_dates=s_parse_dates)

# Partsupp

ps_columnnames = ["PS_PARTKEY", "PS_SUPPKEY", "PS_AVAILQTY", "PS_SUPPLYCOST", "PS_COMMENT"]

for i in range(len(ps_columnnames)):
    ps_columnnames[i] = ps_columnnames[i].lower()

ps_data_types = {
    'ps_partkey': int,
    'ps_suppkey': int,
    'ps_availqty': int,
    'ps_supplycost': float,
    'ps_comment': str
}

ps_parse_dates = []

# Don't set indexes, as we can't access them with Pandas selection!
partsupp = pd.read_table("../data_storage/partsupp.tbl.csv", sep="|", names=ps_columnnames, dtype=ps_data_types, parse_dates=ps_parse_dates)

# Region

r_columnnames = ["R_REGIONKEY", "R_NAME", "R_COMMENT"]

for i in range(len(r_columnnames)):
    r_columnnames[i] = r_columnnames[i].lower()

r_data_types = {
    'r_regionkey': int,
    'r_name': str,
    'r_comment': str
}

r_parse_dates = []

# Don't set indexes, as we can't access them with Pandas selection!
region = pd.read_table("../data_storage/region.tbl.csv", sep="|", names=r_columnnames, dtype=r_data_types, parse_dates=r_parse_dates)

# %%
df_filter_1 = lineitem[['l_partkey', 'l_suppkey', 'l_orderkey', 'l_extendedprice', 'l_discount']]
df_filter_2 = orders[(orders.o_orderdate>='1995-01-01') & (orders.o_orderdate<='1996-12-31') & (~orders.o_orderdate.isnull())]
df_filter_2 = df_filter_2[['o_orderkey', 'o_custkey', 'o_orderdate']]
df_filter_3 = customer[['c_custkey', 'c_nationkey']]
df_filter_4 = nation[['n_nationkey', 'n_regionkey']]
df_filter_5 = region[(region.r_name == 'AMERICA') & (~region.r_name.isnull())]
df_filter_5 = df_filter_5[['r_regionkey', 'r_name']]
df_merge_1 = df_filter_4.merge(df_filter_5, left_on=['n_regionkey'], right_on=['r_regionkey'], how="inner", sort=False)
df_merge_2 = df_filter_3.merge(df_merge_1, left_on=['c_nationkey'], right_on=['n_nationkey'], how="inner", sort=False)
df_merge_3 = df_filter_2.merge(df_merge_2, left_on=['o_custkey'], right_on=['c_custkey'], how="inner", sort=False)
df_merge_4 = df_filter_1.merge(df_merge_3, left_on=['l_orderkey'], right_on=['o_orderkey'], how="inner", sort=False)
df_filter_6 = supplier[['s_suppkey', 's_nationkey']]
df_filter_7 = nation[['n_nationkey', 'n_name']]
df_merge_5 = df_filter_6.merge(df_filter_7, left_on=['s_nationkey'], right_on=['n_nationkey'], how="inner", sort=False)
df_merge_6 = df_merge_4.merge(df_merge_5, left_on=['l_suppkey'], right_on=['s_suppkey'], how="inner", sort=False)
df_filter_8 = part[(part.p_type == 'ECONOMY ANODIZED STEEL') & (~part.p_type.isnull())]
df_filter_8 = df_filter_8[['p_partkey', 'p_type']]
df_merge_7 = df_merge_6.merge(df_filter_8, left_on=['l_partkey'], right_on=['p_partkey'], how="inner", sort=False)
print(list(df_merge_7.columns))
df_merge_7['case_a'] = df_merge_7.apply(lambda x: ( x["l_extendedprice"] * ( 1 - x["l_discount"] )) if ( x["n_name"] == 'BRAZIL' ) else 0, axis=1)
df_merge_7['o_year'] = df_merge_7.o_orderdate.dt.year
df_merge_7['volume'] = ((df_merge_7.l_extendedprice) * (1 - (df_merge_7.l_discount)))
df_group_1 = df_merge_7 \
    .groupby(['o_year'], sort=False) \
    .agg(
        sum_case_a=("case_a", "sum"),
        sum_volume=("volume", "sum"),
    )
df_group_1['sumcase_a'] = df_group_1.sum_case_a
df_group_1['suml_extendedprice1l_discount'] = df_group_1.sum_volume
df_group_1 = df_group_1[['sumcase_a', 'suml_extendedprice1l_discount']]
df_group_1 = df_group_1.reset_index(level=0)
df_aggr_1 = pd.DataFrame()
df_aggr_1['o_year'] = (df_group_1.o_year)
df_aggr_1['mkt_share'] = ((df_group_1.sumcase_a) / (df_group_1.suml_extendedprice1l_discount))
df_aggr_1 = df_aggr_1[['o_year', 'mkt_share']]
df_sort_1 = df_aggr_1.sort_values(by=['o_year'], ascending=[True])
df_limit_1 = df_sort_1.head(1)
#return df_limit_1
# Out:
# ['l_partkey', 'l_suppkey', 'l_orderkey', 'l_extendedprice', 'l_discount', 'o_orderkey', 'o_custkey', 'o_orderdate', 'c_custkey', 'c_nationkey', 'n_nationkey_x', 'n_regionkey', 'r_regionkey', 'r_name', 's_suppkey', 's_nationkey', 'n_nationkey_y', 'n_name', 'p_partkey', 'p_type']

# %%
df_limit_1
# Out:
#    o_year            mkt_share
# 1    1995 0.034435890406654804

# %%
df_scan_1 = nation[['n_nationkey', 'n_name']]
print(f"df_scan_1: {len(df_scan_1)}")
df_scan_2 = region[(region.r_name == 'AMERICA')]
df_scan_2 = df_scan_2[['r_regionkey', 'r_name']]
df_scan_3 = nation[['n_nationkey', 'n_regionkey']]
df_join_1 = df_scan_2.merge(df_scan_3, left_on=['r_regionkey'], right_on=['n_regionkey'], how='inner', sort=False)
print(f"df_join_1: {len(df_join_1)}")
df_scan_4 = part[(part.p_type == 'ECONOMY ANODIZED STEEL')]
df_scan_4 = df_scan_4[['p_partkey', 'p_type']]
df_scan_5 = lineitem[['l_orderkey', 'l_partkey', 'l_suppkey', 'l_extendedprice', 'l_discount']]
df_join_2 = df_scan_4.merge(df_scan_5, left_on=['p_partkey'], right_on=['l_partkey'], how='inner', sort=False)
print(f"df_join_2: {len(df_join_2)}")
df_scan_6 = orders[orders.o_orderdate.between('1995-01-01', '1996-12-31', inclusive='both')]
df_scan_6 = df_scan_6[['o_orderkey', 'o_custkey', 'o_orderdate']]
print(f"df_scan_6: {len(df_scan_6)}")
df_join_3 = df_join_2.merge(df_scan_6, left_on=['l_orderkey'], right_on=['o_orderkey'], how='inner', sort=False)
print(f"df_join_3: {len(df_join_3)}")
df_scan_7 = supplier[['s_suppkey', 's_nationkey']]
df_join_4 = df_join_3.merge(df_scan_7, left_on=['l_suppkey'], right_on=['s_suppkey'], how='inner', sort=False)
df_scan_8 = customer[['c_custkey', 'c_nationkey']]
df_join_5 = df_join_4.merge(df_scan_8, left_on=['o_custkey'], right_on=['c_custkey'], how='inner', sort=False)
print(f"df_join_5: {len(df_join_5)}")
df_join_6 = df_join_1.merge(df_join_5, left_on=['n_nationkey'], right_on=['c_nationkey'], how='inner', sort=False)
print(f"df_join_6: {len(df_join_6)}")
df_join_7 = df_scan_1.merge(df_join_6, left_on=['n_nationkey'], right_on=['s_nationkey'], how='inner', sort=False)
df_join_7['o_orderdate2'] = df_join_7.o_orderdate.dt.year
df_join_7['l_extendedpricel_discount'] = df_join_7.l_extendedprice * (1 - df_join_7.l_discount)
df_join_7['case'] = 0.0
df_join_7.loc[((df_join_7.n_name == 'BRAZIL')), 'case'] = df_join_7.l_extendedpricel_discount
#print(df_join_7.nunique())
print(f"df_join_7: {len(df_join_7)}")
df_group_1 = df_join_7 \
    .groupby(['o_orderdate2'], sort=False, as_index=False) \
    .agg(
        l_extendedpricel_discountsum=('l_extendedpricel_discount', 'sum'),
        casesum=('case', 'sum'),
    )
df_group_1['casesuml_extendedpricel_discountsum'] = (df_group_1.casesum / df_group_1.l_extendedpricel_discountsum)
print(f"df_group_1: {len(df_group_1)}")
df_sort_1 = df_group_1.sort_values(
    by=['o_orderdate2'],
    ascending=[True]
)
df_output_1 = df_sort_1.rename(columns={'o_orderdate2': 'o_year', 'casesuml_extendedpricel_discountsum': 'mkt_share'})
df_output_1 = df_output_1[['o_year', 'mkt_share']]
# Out:
# df_scan_1: 25
# df_join_1: 5
# df_join_2: 43693
# df_scan_6: 457263
# df_join_3: 13389
# df_join_5: 13389
# df_join_6: 2603
# df_join_7: 2603
# df_group_1: 2

# %%
df_output_1
# Out:
#    o_year            mkt_share
# 0    1995 0.034435890406654804
# 1    1996  0.04148552129353032

# %%
df_scan_1 = nation[['n_nationkey', 'n_name']]
df_scan_1 = df_scan_1.rename(columns={'n_nationkey': 'n_nationkey_x', 'n_name': 'n_name_x'})
df_scan_2 = region[(region.r_name == 'AMERICA')]
df_scan_2 = df_scan_2[['r_regionkey', 'r_name']]
df_scan_3 = nation[['n_nationkey', 'n_regionkey']]
df_scan_3 = df_scan_3.rename(columns={'n_nationkey': 'n_nationkey_y', 'n_regionkey': 'n_regionkey_y'})
df_join_1 = df_scan_2.merge(df_scan_3, left_on=['r_regionkey'], right_on=['n_regionkey_y'], how='inner', sort=False)
df_scan_4 = part[(part.p_type == 'ECONOMY ANODIZED STEEL')]
df_scan_4 = df_scan_4[['p_partkey', 'p_type']]
df_scan_5 = lineitem[['l_orderkey', 'l_partkey', 'l_suppkey', 'l_extendedprice', 'l_discount']]
df_join_2 = df_scan_4.merge(df_scan_5, left_on=['p_partkey'], right_on=['l_partkey'], how='inner', sort=False)
df_scan_6 = orders[orders.o_orderdate.between('1995-01-01', '1996-12-31', inclusive='both')]
df_scan_6 = df_scan_6[['o_orderkey', 'o_custkey', 'o_orderdate']]
df_join_3 = df_join_2.merge(df_scan_6, left_on=['l_orderkey'], right_on=['o_orderkey'], how='inner', sort=False)
df_scan_7 = supplier[['s_suppkey', 's_nationkey']]
df_join_4 = df_join_3.merge(df_scan_7, left_on=['l_suppkey'], right_on=['s_suppkey'], how='inner', sort=False)
df_scan_8 = customer[['c_custkey', 'c_nationkey']]
df_join_5 = df_join_4.merge(df_scan_8, left_on=['o_custkey'], right_on=['c_custkey'], how='inner', sort=False)
df_join_6 = df_join_1.merge(df_join_5, left_on=['n_nationkey_y'], right_on=['c_nationkey'], how='inner', sort=False)
df_join_7 = df_scan_1.merge(df_join_6, left_on=['n_nationkey_x'], right_on=['s_nationkey'], how='inner', sort=False)
df_join_7['extractyear_o_orderdate'] = df_join_7.o_orderdate.dt.year
df_join_7['mul_l_extendedprice_sub_l_discount'] = df_join_7.l_extendedprice * (1 - df_join_7.l_discount)
df_join_7['case'] = 0.0
df_join_7.loc[((df_join_7.n_name_x == 'BRAZIL')), 'case'] = df_join_7.mul_l_extendedprice_sub_l_discount
df_group_1 = df_join_7 \
    .groupby(['extractyear_o_orderdate'], sort=False, as_index=False) \
    .agg(
        sum_mul_l_extendedprice_sub_l_discount=('mul_l_extendedprice_sub_l_discount', 'sum'),
        sum_case=('case', 'sum'),
    )
df_group_1['div_sum_case_sum_mul_l_extendedprice_sub_l_discount'] = (df_group_1.sum_case / df_group_1.sum_mul_l_extendedprice_sub_l_discount)
df_output_1 = df_group_1.rename(columns={'extractyear_o_orderdate': 'o_year', 'div_sum_case_sum_mul_l_extendedprice_sub_l_discount': 'mkt_share'})
df_output_1 = df_output_1[['o_year', 'mkt_share']]
